# %% [markdown]
# ## Data Analysis Mathematics, Algorithms and Modeling
#
# ### Team : Group 3
# | Student No  | First Name                  | Last Name     |
# |-------------|-----------------------------|---------------|
# | 9041129     | Nidhi                       | Ahir          |
# | 9016986     | Keerthi                     | Gonuguntla    |
# | 9027375     | Khushbu                     | Lad           |

# %% [markdown]
# ### Problem Analysis Workshop 1
#
# #### Introduction
# In the world, where people are more health conscious and work driven, often face difficulty to prepare meals considering time, ingredients availability and dietary preferences. Although there are a millions of recipes available on internet, it requires efforts to find the one with fits with available resources.
#
# The objective of this project to utilize advanced technologies backed up with large dataset helps to generate customized meal suggestions based on user input.
#
#
# #### Field of Inquiry
#
# - AI, ML and NLP
#    - understand the user’s input
#    - Map User input with tags
#    - Personalised recipe creation
# - Data Analysis
#    - Recipe analysis
#
# #### Problem Statement:
#
# The project's goal is to create a recipe recommendation system powered by AI that makes meal planning easier. A dataset containing 231638 recipes is filtered by ingredients, dietary restrictions, and time constraints to provide users with personalised food recommendations. Based on user choices, this system offers quick, customised meal selections.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

df = pd.read_csv('../Dataset/RAW_recipes.csv')
df.head(5)
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %% [markdown]
# #### Question to consider Dataset
#
# 1. Will it be one-time or ongoing?
#    - Ongoing
#    - We can add new data those are missing in dataset
# 2. Will it be automated?
#    - Yes
# 3. Will it be a major decision or a minor one?
#    - Minor
# 4. Will it be broadly implemented or implemented for one customer or interaction at a time?
#    - Broadly Implimented
# 5. Who will deploy it?
#    - Any user can contribute

# %% [markdown]
# ### Steps to do cleansing
#
# 1. Data import:
#     - Bring information into Excel from an outside source.
# 2. Backup information:
#     - Make a duplicate of the original information in a different workbook.
# 3. Format Check
#     - Check whether the data is formatted in a tabular manner.
# 4. Eliminate duplicates:
#     - Choose the data range, select the Data tab, and then press the Remove Duplicates button. To eliminate empty cells, pick the information, select the Home tab, and then click Find and Select. Click Special and choose Blanks from there.
# 5. Replace missing values:
#     - Replace any absent values in the dataset.
# 6. Format standardization:
#     - Data formats should be standardized.
# 7. Verify spelling: Examine the data for typos and spelling errors.
# 8. Employ Power Query: To automate data cleaning, use Power Query.
# 9. Use Find and Replace: To locate and replace particular.

# %% [markdown]
# ### Dataset Reference
#
# [Kaggle Reference Dataset](https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions)
